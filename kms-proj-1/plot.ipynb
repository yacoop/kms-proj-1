# %%
import matplotlib.pyplot as plt
import pandas
df0 = pandas.read_csv('output.csv', header=None)
df0.columns = ["t", "E", "V", "H", "T", "P"]
# df100 = pandas.read_csv('out100.csv', header=None)
# df100.columns = ["t", "H", "V", "T", "P"]
# df1000 = pandas.read_csv('out1000.csv', header=None)
# df1000.columns = ["t", "H", "V", "T", "P"]
df0
# Out:
#         t        E        V        H        T  P
# 0    0.00  72.0994 -669.286 -597.179  46.2732  0
# 1    0.01  71.7474 -668.934 -597.129  46.0472  0
# 2    0.02  70.8895 -668.076 -597.078  45.4967  0
# 3    0.03  69.5327 -666.719 -597.029  44.6259  0
# 4    0.04  67.6891 -664.876 -596.981  43.4426  0
# ..    ...      ...      ...      ...      ... ..
# 995  9.95  40.3340 -637.520 -597.171  25.8863  0
# 996  9.96  40.1310 -637.317 -597.162  25.7560  0
# 997  9.97  39.8438 -637.030 -597.154  25.5716  0
# 998  9.98  39.4721 -636.658 -597.145  25.3331  0
# 999  9.99  39.0194 -636.206 -597.138  25.0425  0
#
# [1000 rows x 6 columns]

# %%
plt.plot(df0["t"], df0["H"])
plt.ticklabel_format(style = 'plain', useOffset=False)

# %%
plt.plot(df100["t"], df100["H"])
plt.ticklabel_format(style = 'plain', useOffset=False)

# %%
plt.plot(df1000["t"], df1000["H"])
plt.ticklabel_format(style = 'plain', useOffset=False)
